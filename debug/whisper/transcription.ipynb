# %%
#!sudo apt update && sudo apt upgrade (run from web terminal)
#!sudo apt install ffmpeg (run from web terminal)

# %%
# %pip install torchvision==0.13.1
# %pip install torchaudio==0.12.1
# Out:
# Python interpreter will be restarted.
# Collecting torchvision==0.13.1
#   Downloading torchvision-0.13.1-cp39-cp39-manylinux1_x86_64.whl (19.1 MB)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.9/site-packages (from torchvision==0.13.1) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /databricks/python3/lib/python3.9/site-packages (from torchvision==0.13.1) (9.0.1)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.9/site-packages (from torchvision==0.13.1) (4.1.1)
# Collecting torch==1.12.1
#   Downloading torch-1.12.1-cp39-cp39-manylinux1_x86_64.whl (776.4 MB)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.9/site-packages (from torchvision==0.13.1) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests->torchvision==0.13.1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests->torchvision==0.13.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests->torchvision==0.13.1) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests->torchvision==0.13.1) (2021.10.8)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu117
#     Not uninstalling torch at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945
#     Can't uninstall 'torch'. No files were found to uninstall.
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu117
#     Not uninstalling torchvision at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945
#     Can't uninstall 'torchvision'. No files were found to uninstall.
# Successfully installed torch-1.12.1 torchvision-0.13.1
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Collecting torchaudio==0.12.1
#   Downloading torchaudio-0.12.1-cp39-cp39-manylinux1_x86_64.whl (3.7 MB)
# Requirement already satisfied: torch==1.12.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages (from torchaudio==0.12.1) (1.12.1)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.9/site-packages (from torch==1.12.1->torchaudio==0.12.1) (4.1.1)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.12.1
# Python interpreter will be restarted.

# %%
# %pip install pyannote.audio 
# %pip install whisper
# Out:
# Python interpreter will be restarted.
# Collecting whisper
#   Downloading whisper-1.1.10.tar.gz (42 kB)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from whisper) (1.16.0)
# Building wheels for collected packages: whisper
#   Building wheel for whisper (setup.py): started
#   Building wheel for whisper (setup.py): finished with status 'done'
#   Created wheel for whisper: filename=whisper-1.1.10-py3-none-any.whl size=41138 sha256=fa9bab717fc757e4b1a46ef50c2adb268478f9b3a900c0ea2d1a0e3e4790ea41
#   Stored in directory: /root/.cache/pip/wheels/f1/01/8c/1b449563518aa0f8813d044f7a910884e3b8313711becb66d6
# Successfully built whisper
# Installing collected packages: whisper
# Successfully installed whisper-1.1.10
# Python interpreter will be restarted.

# %%
import whisper
import os
import datetime

import subprocess

import torch
import pyannote.audio
from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding

from pyannote.audio import Audio
from pyannote.core import Segment

import wave
import contextlib

from sklearn.cluster import AgglomerativeClustering
import numpy as np
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/torchaudio/_internal/module_utils.py:99: UserWarning: Failed to import soundfile. 'soundfile' backend is not available.
#   warnings.warn("Failed to import soundfile. 'soundfile' backend is not available.")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File <command-146632679197002>:8
#       5 import subprocess
#       7 import torch
# ----> 8 import pyannote.audio
#       9 from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding
#      11 from pyannote.audio import Audio
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/pyannote/audio/__init__.py:29
#      25 except ImportError:
#      26     pass
# ---> 29 from .core.inference import Inference
#      30 from .core.io import Audio
#      31 from .core.model import Model
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/pyannote/audio/core/inference.py:35
#      32 from pytorch_lightning.utilities.memory import is_oom_error
#      34 from pyannote.audio.core.io import AudioFile
# ---> 35 from pyannote.audio.core.model import Model
#      36 from pyannote.audio.core.task import Resolution
#      37 from pyannote.audio.utils.permutation import mae_cost_func, permutate
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/pyannote/audio/core/model.py:46
#      44 from pyannote.audio import __version__
#      45 from pyannote.audio.core.io import Audio
# ---> 46 from pyannote.audio.core.task import Problem, Resolution, Specifications, Task
#      48 CACHE_DIR = os.getenv(
#      49     "PYANNOTE_CACHE",
#      50     os.path.expanduser("~/.cache/torch/pyannote"),
#      51 )
#      52 HF_PYTORCH_WEIGHTS_NAME = "pytorch_model.bin"
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/pyannote/audio/core/task.py:45
#      43 from pyannote.database import Protocol
#      44 from torch.utils.data import DataLoader, Dataset, IterableDataset
# ---> 45 from torch_audiomentations import Identity
#      46 from torch_audiomentations.core.transforms_interface import BaseWaveformTransform
#      47 from torchmetrics import Metric, MetricCollection
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/torch_audiomentations/__init__.py:1
# ----> 1 from .augmentations.background_noise import AddBackgroundNoise
#       2 from .augmentations.band_pass_filter import BandPassFilter
#       3 from .augmentations.band_stop_filter import BandStopFilter
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/torch_audiomentations/augmentations/background_noise.py:10
#       8 from ..core.transforms_interface import BaseWaveformTransform, EmptyPathException
#       9 from ..utils.dsp import calculate_rms
# ---> 10 from ..utils.file import find_audio_files_in_paths
#      11 from ..utils.io import Audio
#      12 from ..utils.object_dict import ObjectDict
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/torch_audiomentations/utils/file.py:5
#       2 from pathlib import Path
#       3 from typing import List, Union
# ----> 5 import soundfile
#       7 from .dsp import resample_audio
#       9 SUPPORTED_EXTENSIONS = (".wav",)
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
#     175     # If it's zero, then this is an absolute import.
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-bacd6b1a-939f-4e19-a983-446625402945/lib/python3.9/site-packages/soundfile.py:142
#     140     _libname = _find_library('sndfile')
#     141     if _libname is None:
# --> 142         raise OSError('sndfile library not found')
#     143     _snd = _ffi.dlopen(_libname)
#     144 except OSError:
#
# OSError: sndfile library not found
